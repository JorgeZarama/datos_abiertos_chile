# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeZarama/datos_abiertos_chile/blob/main/notebook_para_crear_datasets_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crear Conjunto de Datos

# %% [markdown]
# ## 1. Creamos el Dataset en CKAN - Carpeta

# %%
import pandas as pd
import numpy as np
import os
import requests
import http.client
# !pip install openpyxl

# %%
import http.client
import json

conn = http.client.HTTPSConnection("datos.gob.cl")

headers = {
    'Authorization': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJPWmVSQ3l2cm1pNTJTUDdfNkZFdkM2WVkxX0V1eTNibUxqbHRCQjBOV2pJIiwiaWF0IjoxNzQ0MTE2ODkxfQ.wru-Dm8e8-a7rSfNSfv8evcXOYOikUJevXTTqkdNhrA',
    'Content-Type': 'application/json'
}

payload = {
    "name": "este_sera_el_id_del_ds", # Obligatorio URL del Conjunto de Datos
    "title": "En este campo ponemos el título del conjunto de datos", # Obligatorio
    "notes": "Esto es descripción del conjunto de datos", # Descripción Obligatoria
    "author": "Autor del Conjunto de datos", # Obligatorio
    "author_email": "test@email.com", # Obligatorio
    "license_id": "cc-zero", # odc-pddl, cc-by, odc-by
    "owner_org": "division-de-gobierno-digital",
    "period": "Enero 2024",
    "version": "1.0",
    "private": "true",
    "frequency": "1y", #Opcional Frecuancia de actualización se admite los siguientes datos['1d', '7d', '1m', '3m', '4m', '6m', '1y'] (
    "tags": [
    {"name": "API"},
    {"name": "Prueba"},
    {"name": "Datos abiertos"}]
}

json_payload = json.dumps(payload)

conn.request("POST", "/api/action/package_create", json_payload, headers)
response = conn.getresponse()
data = response.read()

print(data.decode("utf-8"))
print(response.status, response.reason)
# Out:
# {"help": "https://datos.gob.cl/api/3/action/help_show?name=package_create", "success": true, "result": {"author": "Autor del Conjunto de datos", "author_email": "test@email.com", "creator_user_id": "09490b69-cf5b-4617-927f-a6b378cf68f0", "frequency": "1y", "id": "c952edfd-b614-405d-baee-23ab3d0a5712", "isopen": true, "license_id": "cc-zero", "license_title": "Creative Commons CCZero", "license_url": "http://www.opendefinition.org/licenses/cc-zero", "maintainer": null, "maintainer_email": null, "metadata_created": "2025-04-08T13:26:50.473918", "metadata_modified": "2025-04-08T13:26:50.473923", "name": "este_sera_el_id_del_ds", "notes": "Esto es descripci\u00f3n del conjunto de datos", "num_resources": 0, "num_tags": 3, "organization": {"id": "a6756acd-bdeb-45c1-bd91-8131fcb98ff4", "name": "division-de-gobierno-digital", "title": "Secretar\u00eda de Gobierno Digital", "type": "organization", "description": "Transformamos digitalmente la relaci\u00f3n del Estado con la ciudadan\u00eda",
# ...

# %% [markdown]
# ## 2. Vamos a crear un archivo del Conjunto de Datos

# %%
rand_matrix = np.random.randint(50,size=(12,12))
frame = pd.DataFrame(rand_matrix , columns=list('ABCDEFGHIJKL'))
display(frame)
# Out:
#      A   B   C   D   E   F   G   H   I   J   K   L
# 0   40  12  48   4  36  16  43  22   5  38  30  17
# 1   20  45  14  39  13  40  45   8  27  41  46  23
# 2   40   7  25  47   7  15  27  25  28   3   3  18
# 3    6  36   9  21  29  37  28  34  23   7  10  15
# 4   42   5  38  49  12  38  12  38   4   3   6  23
# 5    1   2  33  29   5  41  27  32  20  19  38  17
# 6    7  24  33  23  17  42  34  13  28  24  44   2
# 7    5  46  17   4  46   1  19  23   2  49  35  19
# 8    4  10  37   7  16  26  17   9  45  38  31  19
# 9   25  44  28  29   0  45  39  25  29  14  33  25
# 10  29  48   4  43  13  21  29  36  37  45   4  27
# 11   9   3   1  30  14   7  18  17   7  44  45  46

# %%
ruta = os.path.join("recurso_prueba.csv")#crear un CSV
#frame.to_csv(ruta, sep=',', index=False)
frame.to_csv(ruta, sep=',', index=False, encoding='utf-8')

# Guardar XLS
ruta_xls = os.path.join("recurso_prueba.xls")
frame.to_excel(ruta_xls, index=False, engine='openpyxl') # Switched to openpyxl engine

# %% [markdown]
# ## 3. Vamos a subirlo al Conjunto de Datos

# %%
import requests

# Definir la URL, datos y encabezados
url = 'https://datos.gob.cl/api/3/action/resource_create'
data = {
    "package_id": "este_sera_el_id_del_ds",  # Asegúrate de que este nombre de paquete exista
    "description": "recurso de prueba",
    "name": "nombre recurso de prueba",
}
headers = {
    "Authorization": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJPWmVSQ3l2cm1pNTJTUDdfNkZFdkM2WVkxX0V1eTNibUxqbHRCQjBOV2pJIiwiaWF0IjoxNzQ0MTE2ODkxfQ.wru-Dm8e8-a7rSfNSfv8evcXOYOikUJevXTTqkdNhrA'
}
files = {
    'upload': open(ruta, 'rb')  # Asegúrate de que la ruta es válida y el archivo existe
}


# Hacer la solicitud
response = requests.post(url, data=data, headers=headers, files=files)

# Mostrar el estado de la respuesta y el contenido de la respuesta
print(f"Status Code: {response.status_code}")
print(f"Reason: {response.reason}")
print(f"Response Text: {response.text}")
# Out:
# Status Code: 200
# Reason: OK
# Response Text: {"help": "https://datos.gob.cl/api/3/action/help_show?name=resource_create", "success": true, "result": {"cache_last_updated": null, "cache_url": null, "created": "2025-04-08T13:27:35.126552", "datastore_active": false, "datastore_contains_all_records_of_source_file": false, "description": "recurso de prueba", "format": "CSV", "hash": "", "id": "dcb7c459-807b-4574-b065-b0f9bbee4b6d", "last_modified": "2025-04-08T13:27:35.084225", "metadata_modified": "2025-04-08T13:27:35.113241", "mimetype": "text/csv", "mimetype_inner": null, "name": "nombre recurso de prueba", "package_id": "c952edfd-b614-405d-baee-23ab3d0a5712", "position": 0, "resource_type": null, "size": 422, "state": "active", "url": "https://datos.gob.cl/dataset/c952edfd-b614-405d-baee-23ab3d0a5712/resource/dcb7c459-807b-4574-b065-b0f9bbee4b6d/download/recurso_prueba.csv", "url_type": "upload"}}

# %%
url = 'https://datos.gob.cl/api/3/action/resource_create'
data = {
    "package_id": "este_sera_el_id_del_ds",
    "description": "recurso de prueba xls",  # Changed description
    "name": "nombre recurso de prueba",  # Changed name
}
headers = {
    "Authorization": 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJPWmVSQ3l2cm1pNTJTUDdfNkZFdkM2WVkxX0V1eTNibUxqbHRCQjBOV2pJIiwiaWF0IjoxNzQ0MTE2ODkxfQ.wru-Dm8e8-a7rSfNSfv8evcXOYOikUJevXTTqkdNhrA'
}
files = {
    'upload': open(ruta_xls, 'rb')  # Changed file path
}

response = requests.post(url, data=data, headers=headers, files=files)

print(f"Status Code (XLS): {response.status_code}")
print(f"Reason (XLS): {response.reason}")
print(f"Response Text (XLS): {response.text}")
# Out:
# Status Code (XLS): 200
# Reason (XLS): OK
# Response Text (XLS): {"help": "https://datos.gob.cl/api/3/action/help_show?name=resource_create", "success": true, "result": {"cache_last_updated": null, "cache_url": null, "created": "2025-04-08T13:28:16.036817", "datastore_active": false, "datastore_contains_all_records_of_source_file": false, "description": "recurso de prueba xls", "format": "XLS", "hash": "", "id": "6df6f76c-261f-4619-bf95-86f8bed5c1e2", "last_modified": "2025-04-08T13:28:16.005665", "metadata_modified": "2025-04-08T13:28:16.028906", "mimetype": "application/vnd.ms-excel", "mimetype_inner": null, "name": "nombre recurso de prueba", "package_id": "c952edfd-b614-405d-baee-23ab3d0a5712", "position": 2, "resource_type": null, "size": 5658, "state": "active", "url": "https://datos.gob.cl/dataset/c952edfd-b614-405d-baee-23ab3d0a5712/resource/6df6f76c-261f-4619-bf95-86f8bed5c1e2/download/recurso_prueba.xls", "url_type": "upload"}}
